# %%
import json
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
dataset = pd.read_json ('episodes.json')

# %%
print(dataset)
# Out:
#                                              episodes
# 0   {'seasonNum': 1, 'episodeNum': 1, 'episodeTitl...
# 1   {'seasonNum': 1, 'episodeNum': 2, 'episodeTitl...
# 2   {'seasonNum': 1, 'episodeNum': 3, 'episodeTitl...
# 3   {'seasonNum': 1, 'episodeNum': 4, 'episodeTitl...
# 4   {'seasonNum': 1, 'episodeNum': 5, 'episodeTitl...
# 5   {'seasonNum': 1, 'episodeNum': 6, 'episodeTitl...
# 6   {'seasonNum': 1, 'episodeNum': 7, 'episodeTitl...
# 7   {'seasonNum': 1, 'episodeNum': 8, 'episodeTitl...
# 8   {'seasonNum': 1, 'episodeNum': 9, 'episodeTitl...
# 9   {'seasonNum': 1, 'episodeNum': 10, 'episodeTit...
# 10  {'seasonNum': 2, 'episodeNum': 1, 'episodeTitl...
# 11  {'seasonNum': 2, 'episodeNum': 2, 'episodeTitl...
# 12  {'seasonNum': 2, 'episodeNum': 3, 'episodeTitl...
# 13  {'seasonNum': 2, 'episodeNum': 4, 'episodeTitl...
# 14  {'seasonNum': 2, 'episodeNum': 5, 'episodeTitl...
# 15  {'seasonNum': 2, 'episodeNum': 6, 'episodeTitl...
# 16  {'seasonNum': 2, 'episodeNum': 7, 'episodeTitl...
# 17  {'seasonNum': 2, 'episodeNum': 8, 'episodeTitl...
# 18  {'seasonNum': 2, 'episodeNum': 9, 'episodeTitl...
# 19  {'seasonNum': 2, 'episodeNum': 10, 'episodeTit...
# 20  {'seasonNum': 3, 'episodeNum': 1, 'episodeTitl...
# 21  {'seasonNum': 3, 'episodeNum': 2, 'episodeTitl...
# 22  {'seasonNum': 3, 'episodeNum': 3, 'episodeTitl...
# 23  {'seasonNum': 3, 'episodeNum': 4, 'episodeTitl...
# 24  {'seasonNum': 3, 'episodeNum': 5, 'episodeTitl...
# 25  {'seasonNum': 3, 'episodeNum': 6, 'episodeTitl...
# 26  {'seasonNum': 3, 'episodeNum': 7, 'episodeTitl...
# 27  {'seasonNum': 3, 'episodeNum': 8, 'episodeTitl...
# 28  {'seasonNum': 3, 'episodeNum': 9, 'episodeTitl...
# 29  {'seasonNum': 3, 'episodeNum': 10, 'episodeTit...
# ..                                                ...
# 43  {'seasonNum': 5, 'episodeNum': 4, 'episodeTitl...
# 44  {'seasonNum': 5, 'episodeNum': 5, 'episodeTitl...
# 45  {'seasonNum': 5, 'episodeNum': 6, 'episodeTitl...
# 46  {'seasonNum': 5, 'episodeNum': 7, 'episodeTitl...
# 47  {'seasonNum': 5, 'episodeNum': 8, 'episodeTitl...
# 48  {'seasonNum': 5, 'episodeNum': 9, 'episodeTitl...
# 49  {'seasonNum': 5, 'episodeNum': 10, 'episodeTit...
# 50  {'seasonNum': 6, 'episodeNum': 1, 'episodeTitl...
# 51  {'seasonNum': 6, 'episodeNum': 2, 'episodeTitl...
# 52  {'seasonNum': 6, 'episodeNum': 3, 'episodeTitl...
# 53  {'seasonNum': 6, 'episodeNum': 4, 'episodeTitl...
# 54  {'seasonNum': 6, 'episodeNum': 5, 'episodeTitl...
# 55  {'seasonNum': 6, 'episodeNum': 6, 'episodeTitl...
# 56  {'seasonNum': 6, 'episodeNum': 7, 'episodeTitl...
# 57  {'seasonNum': 6, 'episodeNum': 8, 'episodeTitl...
# 58  {'seasonNum': 6, 'episodeNum': 9, 'episodeTitl...
# 59  {'seasonNum': 6, 'episodeNum': 10, 'episodeTit...
# 60  {'seasonNum': 7, 'episodeNum': 1, 'episodeTitl...
# 61  {'seasonNum': 7, 'episodeNum': 2, 'episodeTitl...
# 62  {'seasonNum': 7, 'episodeNum': 3, 'episodeTitl...
# 63  {'seasonNum': 7, 'episodeNum': 4, 'episodeTitl...
# 64  {'seasonNum': 7, 'episodeNum': 5, 'episodeTitl...
# 65  {'seasonNum': 7, 'episodeNum': 6, 'episodeTitl...
# 66  {'seasonNum': 7, 'episodeNum': 7, 'episodeTitl...
# 67  {'seasonNum': 8, 'episodeNum': 1, 'episodeTitl...
# 68  {'seasonNum': 8, 'episodeNum': 2, 'episodeTitl...
# 69  {'seasonNum': 8, 'episodeNum': 3, 'episodeTitl...
# 70  {'seasonNum': 8, 'episodeNum': 4, 'episodeTitl...
# 71  {'seasonNum': 8, 'episodeNum': 5, 'episodeTitl...
# 72  {'seasonNum': 8, 'episodeNum': 6, 'episodeTitl...
#
# [73 rows x 1 columns]

# %%
dataset.head(1)
# Out:
#                                             episodes
# 0  {'seasonNum': 1, 'episodeNum': 1, 'episodeTitl...

# %%
nuevadata = pd.DataFrame(columns=('num', 'nombre', 'descripcion'))
with open('episodes.json') as file:
    data = json.load(file)
    numero = 1
    for episodes in data['episodes']:
        nuevadata.loc[len(nuevadata)]=[numero,episodes['episodeTitle'],episodes['episodeDescription']] 
        print('Numero:',numero)
        print('Nombre del Episodio:', episodes['episodeTitle'])
        print('Breve Descripcion:', episodes['episodeDescription'])
        print('')
        numero = numero +1
# Out:
# Numero: 1
# Nombre del Episodio: Winter Is Coming
# Breve Descripcion: Jon Arryn, the Hand of the King, is dead. King Robert Baratheon plans to ask his oldest friend, Eddard Stark, to take Jon's place. Across the sea, Viserys Targaryen plans to wed his sister to a nomadic warlord in exchange for an army.
#
# Numero: 2
# Nombre del Episodio: The Kingsroad
# Breve Descripcion: While Bran recovers from his fall, Ned takes only his daughters to King's Landing. Jon Snow goes with his uncle Benjen to The Wall. Tyrion joins them.
#
# Numero: 3
# Nombre del Episodio: Lord Snow
# Breve Descripcion: Lord Stark and his daughters arrive at King's Landing to discover the intrigues of the king's realm.
#
# Numero: 4
# Nombre del Episodio: Cripples, Bastards, and Broken Things
# Breve Descripcion: Eddard investigates Jon Arryn's murder. Jon befriends Samwell Tarly, a coward who has come to join the Night's Watch.
#
# Numero: 5
# Nombre del Episodio: The Wolf and the Lion
# Breve Descripcion: Catelyn has captured Tyrion and plans to bring him to her sister, Lysa Arryn, at The Vale, to be tried for his, supposed, crimes against Bran. Robert plans to have Daenerys killed, but Eddard refuses to be a part of it and quits.
#
# Numero: 6
# Nombre del Episodio: A Golden Crown
# Breve Descripcion: While recovering from his battle with Jaime, Eddard is forced to run the kingdom while Robert goes hunting. Tyrion demands a trial by combat for his freedom. Viserys is losing his patience with Drogo.
#
# Numero: 7
# Nombre del Episodio: You Win or You Die
# Breve Descripcion: Robert has been injured while hunting and is dying. Jon and the others finally take their vows to the Night's Watch. A man, sent by Robert, is captured for trying to poison Daenerys. Furious, Drogo vows to attack the Seven Kingdoms.
#
# Numero: 8
# Nombre del Episodio: The Pointy End
# Breve Descripcion: Eddard and his men are betrayed and captured by the Lannisters. When word reaches Robb, he plans to go to war to rescue them. The White Walkers attack The Wall. Tyrion returns to his father with some new friends.
#
# Numero: 9
# Nombre del Episodio: Baelor
# Breve Descripcion: Robb goes to war against the Lannisters. Jon finds himself struggling on deciding if his place is with Robb or the Night's Watch. Drogo has fallen ill from a fresh battle wound. Daenerys is desperate to save him.
#
# Numero: 10
# Nombre del Episodio: Fire and Blood
# Breve Descripcion: With Ned dead, Robb vows to get revenge on the Lannisters. Jon must officially decide if his place is with Robb or the Night's Watch. Daenerys says her final goodbye to Drogo.
#
# Numero: 11
# Nombre del Episodio: The North Remembers
# Breve Descripcion: Tyrion arrives at King's Landing to take his father's place as Hand of the King. Stannis Baratheon plans to take the Iron Throne for his own. Robb tries to decide his next move in the war. The Night's Watch arrive at the house of Craster.
#
# Numero: 12
# Nombre del Episodio: The Night Lands
# Breve Descripcion: Arya makes friends with Gendry. Tyrion tries to take control of the small council. Theon arrives at his home, Pyke, in order to persuade his father into helping Robb with the war. Jon tries to investigate Craster's secret.
#
# Numero: 13
# Nombre del Episodio: What Is Dead May Never Die
# Breve Descripcion: Tyrion tries to see who he can trust in the small council. Catelyn visits Renly to try and persuade him to join Robb in the war. Theon must decide if his loyalties lie with his own family or with Robb.
#
# Numero: 14
# Nombre del Episodio: Garden of Bones
# Breve Descripcion: Lord Baelish arrives at Renly's camp just before he faces off against Stannis. Daenerys and her company are welcomed into the city of Qarth. Arya, Gendry, and Hot Pie find themselves imprisoned at Harrenhal.
#
# Numero: 15
# Nombre del Episodio: The Ghost of Harrenhal
# Breve Descripcion: Tyrion investigates a secret weapon that King Joffrey plans to use against Stannis. Meanwhile, as a token for saving his life, Jaqen H'ghar offers to kill three people that Arya chooses.
#
# Numero: 16
# Nombre del Episodio: The Old Gods and the New
# Breve Descripcion: Theon seizes control of Winterfell. Jon captures a wildling, named Ygritte. The people of King's Landing begin to turn against King Joffrey. Daenerys looks to buy ships to sail for the Seven Kingdoms.
#
# Numero: 17
# Nombre del Episodio: A Man Without Honor
# Breve Descripcion: Bran and Rickon have escaped Winterfell. Theon tries to hunt them down. Daenerys' dragons have been stolen. Jon travels through the wilderness with Ygritte as his prisoner. Sansa has bled and is now ready to have Joffrey's children.
#
# Numero: 18
# Nombre del Episodio: The Prince of Winterfell
# Breve Descripcion: Stannis is just days from King's Landing. Tyrion prepares for his arrival. Jon and Qhorin are taken prisoner by the wildlings. Catelyn is arrested for releasing Jaime. Arya, Gendry, and Hot Pie plan to escape from Harrenhal.
#
# Numero: 19
# Nombre del Episodio: Blackwater
# Breve Descripcion: Stannis Baratheon's fleet and army arrive at King's Landing and the battle for the city begins. Cersei plans for her and her children's future.
#
# Numero: 20
# Nombre del Episodio: Valar Morghulis
# Breve Descripcion: Joffrey puts Sansa aside for Margaery Tyrell. Robb marries Talisa Maegyr. Jon prepares to meet Mance Rayder. Arya says farewell to Jaqen H'ghar. Daenerys tries to rescue her dragons.
#
# Numero: 21
# Nombre del Episodio: Valar Dohaeris
# Breve Descripcion: Jon is brought before Mance Rayder, the King Beyond the Wall, while the Night's Watch survivors retreat south. In King's Landing, Tyrion asks for his reward. Littlefinger offers Sansa a way out.
#
# Numero: 22
# Nombre del Episodio: Dark Wings, Dark Words
# Breve Descripcion: Bran and company meet Jojen and Meera Reed. Arya, Gendry, and Hot Pie meet the Brotherhood. Jaime travels through the wilderness with Brienne. Sansa confesses her true feelings about Joffrey to Margaery.
#
# Numero: 23
# Nombre del Episodio: Walk of Punishment
# Breve Descripcion: Robb and Catelyn arrive at Riverrun for Lord Hoster Tully's funeral. Tywin names Tyrion the new Master of Coin. Arya says goodbye to Hot Pie. The Night's Watch returns to Craster's. Brienne and Jaime are taken prisoner.
#
# Numero: 24
# Nombre del Episodio: And Now His Watch Is Ended
# Breve Descripcion: Jaime mopes over his lost hand. Cersei is growing uncomfortable with the Tyrells. The Night's Watch is growing impatient with Craster. Daenerys buys the Unsullied.
#
# Numero: 25
# Nombre del Episodio: Kissed by Fire
# Breve Descripcion: Robb's army is falling apart. Jaime reveals a story, to Brienne, that he has never told anyone. Jon breaks his vows. The Hound is granted his freedom. The Lannisters hatch a new plan.
#
# Numero: 26
# Nombre del Episodio: The Climb
# Breve Descripcion: Jon and the wildlings scale The Wall. The Brotherhood sells Gendry to Melisandre. Robb does what he can to win back the Freys. Tyrion tells Sansa about their engagement.
#
# Numero: 27
# Nombre del Episodio: The Bear and the Maiden Fair
# Breve Descripcion: Jon and the wildlings travel south of The Wall. Talisa tells Robb that she's pregnant. Arya runs away from the Brotherhood. Daenerys arrives at Yunkai. Jaime leaves Brienne behind at Harrenhal.
#
# Numero: 28
# Nombre del Episodio: Second Sons
# Breve Descripcion: Daenerys tries to persuade the Second Sons to join her against Yunkai. Stannis releases Davos from the dungeons. Sam and Gilly are attacked by a White Walker. Sansa and Tyrion wed.
#
# Numero: 29
# Nombre del Episodio: The Rains of Castamere
# Breve Descripcion: Robb and Catelyn arrive at the Twins for the wedding. Jon is put to the test to see where his loyalties truly lie. Bran's group decides to split up. Daenerys plans an invasion of Yunkai.
#
# Numero: 30
# Nombre del Episodio: Mhysa
# Breve Descripcion: Bran and company travel beyond The Wall. Sam returns to Castle Black. Jon says good bye to Ygritte. Jaime returns to King's Landing. The Night's Watch asks for help from Stannis.
#
# Numero: 31
# Nombre del Episodio: Two Swords
# Breve Descripcion: Tyrion welcomes a guest to King's Landing. At Castle Black, Jon stands trial. Daenerys is pointed to Meereen, the mother of all slave cities. Arya runs into an old enemy.
#
# Numero: 32
# Nombre del Episodio: The Lion and the Rose
# Breve Descripcion: Joffrey and Margaery's wedding has come. Tyrion breaks up with Shae. Ramsay tries to prove his worth to his father. Bran and company find a Weirwood tree.
#
# Numero: 33
# Nombre del Episodio: Breaker of Chains
# Breve Descripcion: Tyrion is arrested for the murder of Joffrey and awaits trial. Sansa escapes King's Landing. Sam sends Gilly to Mole's Town as the Night's Watch finds itself in a tight spot. Meereen challenges Daenerys.
#
# Numero: 34
# Nombre del Episodio: Oathkeeper
# Breve Descripcion: Jaime entrusts a task to Brienne. Daenerys frees Meereen. Jon is given permission to lead a group of Night's Watchmen to Craster's Keep. Bran and company are taken hostage.
#
# Numero: 35
# Nombre del Episodio: First of His Name
# Breve Descripcion: Tommen is crowned King of the Seven Kingdoms. Cersei builds her case against Tyrion. Sansa and Lord Baelish arrive at the Eyrie. The Night's Watch attacks Craster's Keep.
#
# Numero: 36
# Nombre del Episodio: The Laws of Gods and Men
# Breve Descripcion: Tyrion's trial has come. Yara and her troops storm the Dreadfort to free Theon. Daenerys meets Hizdar zo Loraq. Stannis makes a deal with the Iron Bank of Braavos.
#
# Numero: 37
# Nombre del Episodio: Mockingbird
# Breve Descripcion: Tyrion tries to find a champion. Daenerys sleeps with Daario. The Hound becomes wounded. Jon's advice is ignored at Castle Black. Brienne and Podrick receive a tip on Arya's whereabouts.
#
# Numero: 38
# Nombre del Episodio: The Mountain and the Viper
# Breve Descripcion: Theon helps Ramsay seize Moat Cailin. The wildlings attack Mole's Town. Sansa comes up with a story to protect Lord Baelish. Daenerys finds out a secret about Ser Jorah. Oberyn Martell faces Ser Gregor Clegane.
#
# Numero: 39
# Nombre del Episodio: The Watchers on the Wall
# Breve Descripcion: The battle between the Night's Watch and the Wildlings has come.
#
# Numero: 40
# Nombre del Episodio: The Children
# Breve Descripcion: The Night's Watch story continues, with surprising developments. Daenerys experiences new consequences. Brienne and Podrick have an unexpected encounter. Bran achieves a goal, while Tyrion makes an important discovery.
#
# Numero: 41
# Nombre del Episodio: The Wars to Come
# Breve Descripcion: Cersei and Jaime adjust to a world without Tywin. Tyrion and Varys arrive at Pentos. In Meereen, a new enemy emerges. Jon is caught between two kings.
#
# Numero: 42
# Nombre del Episodio: The House of Black and White
# Breve Descripcion: Arya arrives in Braavos. Jaime takes on a secret mission. Ellaria Sand seeks revenge for Oberyn's death. Stannis makes Jon a generous offer as the Night's Watch elects a new Lord Commander. Daenerys is faced with a difficult decision.
#
# Numero: 43
# Nombre del Episodio: High Sparrow
# Breve Descripcion: Tommen and Margaery wed. Arya has trouble adapting to her new life. Littlefinger reveals his plans to Sansa. Jon gives his first orders as Lord Commander. Tyrion and Varys arrive in Volantis.
#
# Numero: 44
# Nombre del Episodio: Sons of the Harpy
# Breve Descripcion: Jorah Mormont sets sail alongside his prisoner, Tyrion. Cersei makes a move against the Tyrells. Jaime and Bronn sneak into Dorne. Ellaria and the Sand Snakes make their plans. Melisandre tempts Jon. The Harpies attack.
#
# Numero: 45
# Nombre del Episodio: Kill the Boy
# Breve Descripcion: Daenerys arrests the heads of Meereen's great families. Jon makes a difficult decision. Theon is forced to face Sansa. Stannis rides south. Tyrion and Jorah enter the ruins of Old Valyria.
#
# Numero: 46
# Nombre del Episodio: Unbowed, Unbent, Unbroken
# Breve Descripcion: Arya is put to the test. Tyrion and Jorah are captured by slavers. Loras Tyrell is judged by the Sparrows. Jaime and Bronn face the Sand Snakes. Sansa marries Ramsay Bolton.
#
# Numero: 47
# Nombre del Episodio: The Gift
# Breve Descripcion: Jon heads east as trouble begins to stir for Sam and Gilly at Castle Black. Sansa asks Theon for help. Tyrion and Jorah are sold as slaves. Cersei savors her triumph over the Tyrells as new plots are developed in the shadows.
#
# Numero: 48
# Nombre del Episodio: Hardhome
# Breve Descripcion: Tyrion advises Daenerys. Sansa forces Theon to tell her a secret. Cersei remains stubborn. Arya meets her first target. Jon and Tormund meet with the Wildling Elders.
#
# Numero: 49
# Nombre del Episodio: The Dance of Dragons
# Breve Descripcion: Jon and the Wildlings return to Castle Black. Jaime meets with Doran Martell. Stannis makes a hard choice. Arya runs into Ser Meryn Trant. Daenerys attends the grand reopening of the fighting pits.
#
# Numero: 50
# Nombre del Episodio: Mother's Mercy
# Breve Descripcion: Stannis arrives at Winterfell. Tyrion runs Meereen as Daario and Jorah go after Daenerys. Jaime and Myrcella leave Dorne. Jon sends Sam and Gilly to Oldtown. Arya challenges the Many-Faced God. Cersei confesses her sins.
#
# Numero: 51
# Nombre del Episodio: The Red Woman
# Breve Descripcion: The fate of Jon Snow is revealed. Daenerys is brought before Khal Moro. Tyrion gets used to living in Meereen. Ramsay sends his dogs after Theon and Sansa. Ellaria and the Sand Snakes make their move. Cersei mourns for Myrcella.
#
# Numero: 52
# Nombre del Episodio: Home
# Breve Descripcion: Bran trains with the Three-Eyed Raven. Tommen meets with Cersei. Tyrion makes a bold move. Theon leaves while at Pyke new issues arise. Ramsay's brother is born. Davos asks Melisandre for a miracle.
#
# Numero: 53
# Nombre del Episodio: Oathbreaker
# Breve Descripcion: Daenerys arrives at Vaes Dothrak. Sam and Gilly sail for Horn Hill. Arya trains as No One. Varys finds information on the Sons of the Harpy. Ramsay receives a gift. Tommen meets with the High Sparrow. At Castle Black, a miracle occurs.
#
# Numero: 54
# Nombre del Episodio: Book of the Stranger
# Breve Descripcion: Sansa arrives at Castle Black. Tyrion makes a deal with the Slave Masters. Jorah and Daario sneak into Vaes Dothrak. Ramsay sends a letter to Jon. Theon arrives at Pyke. Cersei and Olenna Tyrell plot against the High Sparrow.
#
# Numero: 55
# Nombre del Episodio: The Door
# Breve Descripcion: Sansa and Jon make plans. Arya is given another chance to prove herself. Jorah confesses a secret to Daenerys. Tyrion meets with a Red Priestess. Yara finds her rule tested. Bran discovers the origin of the White Walkers.
#
# Numero: 56
# Nombre del Episodio: Blood of My Blood
# Breve Descripcion: Bran and Meera find a new ally. Gilly meets Sam's family. Arya makes a difficult choice. The Lannisters and Tyrells march against the High Sparrow.
#
# Numero: 57
# Nombre del Episodio: The Broken Man
# Breve Descripcion: Jon and Sansa gather troops. Jaime arrives at Riverrun. Olenna Tyrell plans to leave King's Landing. Theon and Yara plan a destination. Arya makes plans to leave.
#
# Numero: 58
# Nombre del Episodio: No One
# Breve Descripcion: Brienne arrives at Riverrun. Arya seeks shelter. Jaime meets with Edmure Tully. Cersei challenges the Faith. Sandor Clegane hunts for revenge. Tyrion faces the consequences of earlier decisions.
#
# Numero: 59
# Nombre del Episodio: Battle of the Bastards
# Breve Descripcion: Jon and Sansa face Ramsay Bolton on the fields of Winterfell. Daenerys strikes back at her enemies. Theon and Yara arrive in Meereen.
#
# Numero: 60
# Nombre del Episodio: The Winds of Winter
# Breve Descripcion: Cersei and Loras Tyrell stand trial by the gods. Daenerys prepares to set sail for Westeros. Davos confronts Melisandre. Sam and Gilly arrive in Oldtown. Bran discovers a long kept secret. Lord Frey has an uninvited guest.
#
# Numero: 61
# Nombre del Episodio: Dragonstone
# Breve Descripcion: Jon organizes the North's defenses. Cersei tries to even the odds. Daenerys comes home. Arya reminds the Freys "The North remembers". Sam adapts to life in Oldtown. Night King makes his way south.
#
# Numero: 62
# Nombre del Episodio: Stormborn
# Breve Descripcion: Daenerys receives an unexpected visitor. Jon faces resistance. Tyrion plans the conquest of Westeros. Cersei gathers her allies. Arya has a reunion with old friends. Sam risks his career and life.
#
# Numero: 63
# Nombre del Episodio: The Queen's Justice
# Breve Descripcion: Daenerys and Jon meet. Cersei gains a new ally. Sansa receives an unexpected visitor. Sam is confronted for his actions.
#
# Numero: 64
# Nombre del Episodio: The Spoils of War
# Breve Descripcion: Daenerys takes matters into her own hands. Arya reaches her destination. Jaime and Bronn collect the spoils from the war with the Tyrells.
# Numero: 65
# Nombre del Episodio: Eastwatch
# Breve Descripcion: Daenerys demands loyalty from the surviving Lannister soldiers; Jon heeds Bran's warning about White Walkers on the move; Cersei vows to vanquish anyone or anything that stands in her way.
#
# Numero: 66
# Nombre del Episodio: Beyond the Wall
# Breve Descripcion: Jon and his team go beyond the wall to capture a wight. Daenerys has to make a tough decision.
#
# Numero: 67
# Nombre del Episodio: The Dragon and the Wolf
# Breve Descripcion: Season finale of the epic series.
#
# Numero: 68
# Nombre del Episodio: Winterfell
# Breve Descripcion: Jon and Daenerys arrive in Winterfell and are met with skepticism. Sam learns about the fate of his family. Cersei gives Euron the reward he aims for. Theon follows his heart.
#
# Numero: 69
# Nombre del Episodio: A Knight of the Seven Kingdoms
# Breve Descripcion: The battle at Winterfell is approaching. Jaime is confronted with the consequences of the past. A tense interaction between Sansa and Daenerys follows.
#
# Numero: 70
# Nombre del Episodio: The Long Night
# Breve Descripcion: The Night King and his army have arrived at Winterfell and the great battle begins.
#
# Numero: 71
# Nombre del Episodio: The Last of the Starks
# Breve Descripcion: In the wake of a costly victory, Jon and Daenerys look to the south as Tyrion eyes a compromise that could save countless lives.
#
# Numero: 72
# Nombre del Episodio: The Bells
# Breve Descripcion: Daenerys and Cersei weigh their options as an epic conflict looms at King's Landing.
#
# Numero: 73
# Nombre del Episodio: The Iron Throne
# Breve Descripcion: In the aftermath of the devastating attack on King's Landing, Daenerys must face the survivors.

# %%
print(nuevadata)
# Out:
#    num                                 nombre  \
# 0    1                       Winter Is Coming
# 1    2                          The Kingsroad
# 2    3                              Lord Snow
# 3    4  Cripples, Bastards, and Broken Things
# 4    5                  The Wolf and the Lion
# 5    6                         A Golden Crown
# 6    7                     You Win or You Die
# 7    8                         The Pointy End
# 8    9                                 Baelor
# 9   10                         Fire and Blood
# 10  11                    The North Remembers
# 11  12                        The Night Lands
# 12  13             What Is Dead May Never Die
# 13  14                        Garden of Bones
# 14  15                 The Ghost of Harrenhal
# 15  16               The Old Gods and the New
# 16  17                    A Man Without Honor
# 17  18               The Prince of Winterfell
# 18  19                             Blackwater
# 19  20                        Valar Morghulis
# 20  21                         Valar Dohaeris
# 21  22                 Dark Wings, Dark Words
# 22  23                     Walk of Punishment
# 23  24             And Now His Watch Is Ended
# 24  25                         Kissed by Fire
# 25  26                              The Climb
# 26  27           The Bear and the Maiden Fair
# 27  28                            Second Sons
# 28  29                 The Rains of Castamere
# 29  30                                  Mhysa
# ..  ..                                    ...
# 43  44                      Sons of the Harpy
# 44  45                           Kill the Boy
# 45  46              Unbowed, Unbent, Unbroken
# 46  47                               The Gift
# 47  48                               Hardhome
# 48  49                   The Dance of Dragons
# 49  50                         Mother's Mercy
# 50  51                          The Red Woman
# 51  52                                   Home
# 52  53                            Oathbreaker
# 53  54                   Book of the Stranger
# 54  55                               The Door
# 55  56                      Blood of My Blood
# 56  57                         The Broken Man
# 57  58                                 No One
# 58  59                 Battle of the Bastards
# 59  60                    The Winds of Winter
# 60  61                            Dragonstone
# 61  62                              Stormborn
# 62  63                    The Queen's Justice
# 63  64                      The Spoils of War
# 64  65                              Eastwatch
# 65  66                        Beyond the Wall
# 66  67                The Dragon and the Wolf
# 67  68                             Winterfell
# 68  69         A Knight of the Seven Kingdoms
# 69  70                         The Long Night
# 70  71                 The Last of the Starks
# 71  72                              The Bells
# 72  73                        The Iron Throne
#
#                                           descripcion
# 0   Jon Arryn, the Hand of the King, is dead. King...
# 1   While Bran recovers from his fall, Ned takes o...
# 2   Lord Stark and his daughters arrive at King's ...
# 3   Eddard investigates Jon Arryn's murder. Jon be...
# 4   Catelyn has captured Tyrion and plans to bring...
# 5   While recovering from his battle with Jaime, E...
# 6   Robert has been injured while hunting and is d...
# 7   Eddard and his men are betrayed and captured b...
# 8   Robb goes to war against the Lannisters. Jon f...
# 9   With Ned dead, Robb vows to get revenge on the...
# 10  Tyrion arrives at King's Landing to take his f...
# 11  Arya makes friends with Gendry. Tyrion tries t...
# 12  Tyrion tries to see who he can trust in the sm...
# 13  Lord Baelish arrives at Renly's camp just befo...
# 14  Tyrion investigates a secret weapon that King ...
# 15  Theon seizes control of Winterfell. Jon captur...
# 16  Bran and Rickon have escaped Winterfell. Theon...
# 17  Stannis is just days from King's Landing. Tyri...
# 18  Stannis Baratheon's fleet and army arrive at K...
# 19  Joffrey puts Sansa aside for Margaery Tyrell. ...
# 20  Jon is brought before Mance Rayder, the King B...
# 21  Bran and company meet Jojen and Meera Reed. Ar...
# 22  Robb and Catelyn arrive at Riverrun for Lord H...
# 23  Jaime mopes over his lost hand. Cersei is grow...
# 24  Robb's army is falling apart. Jaime reveals a ...
# 25  Jon and the wildlings scale The Wall. The Brot...
# 26  Jon and the wildlings travel south of The Wall...
# 27  Daenerys tries to persuade the Second Sons to ...
# 28  Robb and Catelyn arrive at the Twins for the w...
# 29  Bran and company travel beyond The Wall. Sam r...
# ..                                                ...
# 43  Jorah Mormont sets sail alongside his prisoner...
# 44  Daenerys arrests the heads of Meereen's great ...
# 45  Arya is put to the test. Tyrion and Jorah are ...
# 46  Jon heads east as trouble begins to stir for S...
# 47  Tyrion advises Daenerys. Sansa forces Theon to...
# 48  Jon and the Wildlings return to Castle Black. ...
# 49  Stannis arrives at Winterfell. Tyrion runs Mee...
# 50  The fate of Jon Snow is revealed. Daenerys is ...
# 51  Bran trains with the Three-Eyed Raven. Tommen ...
# 52  Daenerys arrives at Vaes Dothrak. Sam and Gill...
# 53  Sansa arrives at Castle Black. Tyrion makes a ...
# 54  Sansa and Jon make plans. Arya is given anothe...
# 55  Bran and Meera find a new ally. Gilly meets Sa...
# 56  Jon and Sansa gather troops. Jaime arrives at ...
# 57  Brienne arrives at Riverrun. Arya seeks shelte...
# 58  Jon and Sansa face Ramsay Bolton on the fields...
# 59  Cersei and Loras Tyrell stand trial by the god...
# 60  Jon organizes the North's defenses. Cersei tri...
# 61  Daenerys receives an unexpected visitor. Jon f...
# 62  Daenerys and Jon meet. Cersei gains a new ally...
# 63  Daenerys takes matters into her own hands. Ary...
# 64  Daenerys demands loyalty from the surviving La...
# 65  Jon and his team go beyond the wall to capture...
# 66                  Season finale of the epic series.
# 67  Jon and Daenerys arrive in Winterfell and are ...
# 68  The battle at Winterfell is approaching. Jaime...
# 69  The Night King and his army have arrived at Wi...
# 70  In the wake of a costly victory, Jon and Daene...
# 71  Daenerys and Cersei weigh their options as an ...
# 72  In the aftermath of the devastating attack on ...
#
# [73 rows x 3 columns]

# %%
nuevadata.head(5)
# Out:
#   num                                 nombre  \
# 0   1                       Winter Is Coming
# 1   2                          The Kingsroad
# 2   3                              Lord Snow
# 3   4  Cripples, Bastards, and Broken Things
# 4   5                  The Wolf and the Lion
#
#                                          descripcion
# 0  Jon Arryn, the Hand of the King, is dead. King...
# 1  While Bran recovers from his fall, Ned takes o...
# 2  Lord Stark and his daughters arrive at King's ...
# 3  Eddard investigates Jon Arryn's murder. Jon be...
# 4  Catelyn has captured Tyrion and plans to bring...

# %%
text = nuevadata.descripcion[0]
text
# Out:
# "Jon Arryn, the Hand of the King, is dead. King Robert Baratheon plans to ask his oldest friend, Eddard Stark, to take Jon's place. Across the sea, Viserys Targaryen plans to wed his sister to a nomadic warlord in exchange for an army."

# %%
# Creando y generando una imagen de nube de palabras.
wordcloud = WordCloud().generate(text)

# Mostrando la imagen generada
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Bajando el max_font_size, cambiando el número máximo de palabras y colocando un fodo de color
wordcloud = WordCloud(max_font_size=100, max_words=150, background_color="Red").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Guardando la imagen
wordcloud.to_file("WordCloud1.png")

# %%
# Combinaciones de palabras de la columna description
capitulonombre = " ".join(review for review in nuevadata.nombre)
print ("Hay {} palabras en la combinación de los nombres de capitulos.".format(len(capitulonombre)))

capitulodescripcion = " ".join(review for review in nuevadata.descripcion)
print ("Hay {} palabras en la combinación de la descripcion del capitulo".format(len(capitulodescripcion)))
# Out:
# Hay 1261 palabras en la combinación de los nombres de capitulos.
# Hay 13155 palabras en la combinación de la descripcion del capitulo

# %%
# Generate a word cloud image nombre capitulo
wordcloud = WordCloud(background_color="black").generate(capitulonombre)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#Nombre capitulo con stopwords
stopwords = set(STOPWORDS)
stopwords.update([])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="black").generate(capitulonombre)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Generate a word cloud image nombre capitulo
wordcloud = WordCloud(background_color="black").generate(capitulodescripcion)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#Nombre capitulo con stopwords
stopwords = set(STOPWORDS)
stopwords.update(["arrive"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="black").generate(capitulodescripcion)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Creamos un array de una imagen de mascara
wine_mask = np.array(Image.open("dragon.png"))
wine_mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [239, 239, 239]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [238, 238, 238]],
#
#        ...,
#
#        [[238, 238, 238],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255]],
#
#        [[238, 238, 238],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255]],
#
#        [[239, 239, 239],
#         [238, 238, 238],
#         [238, 238, 238],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
# Función para transformar los valores a: 0 ó 255

def transform_format(val):
    if val == 0:
        return 255
    else:
        return 0

# %%
# Transforma la máscara en una nueva función
transformed_wine_mask = np.ndarray((wine_mask.shape[0],wine_mask.shape[1]), np.int32)

for i in range(len(wine_mask)):
    transformed_wine_mask[i] = list(map(transform_format, wine_mask[i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-73bcdec0a480> in <module>
#       3
#       4 for i in range(len(wine_mask)):
# ----> 5     transformed_wine_mask[i] = list(map(transform_format, wine_mask[i]))
#
# <ipython-input-60-6a124632a443> in transform_format(val)
#       2
#       3 def transform_format(val):
# ----> 4     if val == 0:
#       5         return 255
#       6     else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# Creando una imagen de nube de palabras
wc = WordCloud(background_color="black", max_words=1000, mask=transformed_wine_mask,
               stopwords=stopwords, contour_width=3, contour_color='firebrick')

# Generate a wordcloud
wc.generate(text)

# store to file
wc.to_file("img.png")

# show
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
stopwordspanish
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-669ce8a72a22> in <module>
# ----> 1 stopwordspanish
#
# NameError: name 'stopwordspanish' is not defined
